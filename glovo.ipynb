# %% [markdown]
# <a href="https://colab.research.google.com/github/Bversleg/Bversleg/blob/main/glovo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import pandas as pd

segments_df = pd.read_csv('data_business_segments.csv')
segments_df
countries_df = pd.read_csv('data_countries.csv')
countries_df
finance_df = pd.read_csv('data_finance.csv')
finance_df
integrations_df = pd.read_csv('data_integrations.csv')
integrations_df
operations_df = pd.read_csv('data_operations.csv')
operations_df
orders_df = pd.read_csv('data_orders.csv')
orders_df
vertical_df = pd.read_csv('data_vertical.csv')
vertical_df
# Out:
#        partner_id    vertical
# 0          169385        Food
# 1          230660        Food
# 2          247635        Food
# 3          341110        Food
# 4          368335        Food
# ...           ...         ...
# 46203     5266435  Q-commerce
# 46204     5665210        Food
# 46205     6446560        Food
# 46206     6512635        Food
# 46207     7269060  Q-commerce
#
# [46208 rows x 2 columns]

# %%
print(vertical_df.shape, orders_df.shape,operations_df.shape,integrations_df.shape,finance_df.shape,countries_df.shape,segments_df.shape)
# Out:
# (46208, 2) (190708, 4) (190708, 4) (46208, 2) (190708, 4) (46208, 2) (46208, 2)

# %%
dimentions_df = pd.merge(integrations_df, countries_df, on=['partner_id']).merge(segments_df, on=['partner_id']).merge(vertical_df, on=['partner_id'])

# %%
dimentions_df.dropna(axis='index', how='any')
# Out:
#        partner_id  is_integrated country business_segment    vertical
# 0          169385          False      ES       Local Hero        Food
# 1          230660          False      PT        Long Tail        Food
# 2          247635           True      ES            Chain        Food
# 3          341110          False      ES            Chain        Food
# 4          368335          False      ES        Long Tail        Food
# ...           ...            ...     ...              ...         ...
# 46203     5266435           True      UA       Q-Commerce  Q-commerce
# 46204     5665210          False      ES       Local Hero        Food
# 46205     6446560          False      ES        Long Tail        Food
# 46206     6512635          False      ES        Long Tail        Food
# 46207     7269060           True      UA       Q-Commerce  Q-commerce
#
# [46206 rows x 5 columns]

# %%
daily_metrics_df = orders_df.merge(finance_df, on=['partner_id','date']).merge(operations_df, on=['partner_id','date'])

# %%
daily_metrics_df.dropna(axis='index', how='any')
# Out:
#               date  partner_id  orders_daily  connected_hours  avg_order_cost  \
# 0       2021-08-12      169385           1.0                7        4.663740
# 1       2021-08-12      230660          10.0                0        5.677032
# 2       2021-08-12      247635           5.0                0       19.922868
# 3       2021-08-12      341110           3.0                6       18.669470
# 4       2021-08-12      368335           3.0                0       17.023120
# ...            ...         ...           ...              ...             ...
# 190703  2021-08-18     7966135           1.0                0        5.098980
# 190704  2021-08-18     8200460           2.0                1       10.084515
# 190705  2021-08-18     8279060           1.0                2       12.322500
# 190706  2021-08-18     8484310           1.0                9       10.698690
# 190707  2021-08-18     8615535           1.0                6       10.242120
#
# ...

# %%
grouped_metrics_df = daily_metrics_df.groupby('partner_id').agg({'orders_daily':'sum',
                                            'connected_hours': 'sum',
                                            'avg_order_cost': 'mean',
                                            'avg_order_revenue': 'mean',
                                            'avg_delivery_time_min': 'mean',
                                            'avg_preparation_time_min': 'mean'}).reset_index()

# %%
final_df = dimentions_df.merge(grouped_metrics_df, on=['partner_id'])

# %%
final_df.to_csv('glovo_data.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
final_df.to_csv('/content/drive/My Drive/glovo_data.csv', index=False)
